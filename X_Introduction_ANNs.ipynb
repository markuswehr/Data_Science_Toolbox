# %% [markdown]
# ## X. Introduction to Artificial Neural Networks
#
# Pages 253 to 263 of 'Hands-on-ML give an amazing introduction into Artificial Neural Networks (ANNs). Here, I will only present the implementation of an ANN using tensorflow. Tensorflow's high-level API *TF.Learn* makes it very easy to train a deep neural network. In fact, following code trains a DNN for classification with two hidden layers (or Perceptrons), one with 300 neurons and one with 100 neurons.In the end, there is a softmax layer with 10 neurons (=10 classes).
#
# ### X.1 Training an MLP with TensorFlow's High-Level API

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

iris = load_iris() 
X = iris.data[:, (2, 3)]  # petal length, petal width 
y = (iris.target == 0).astype(np.int)  # Iris Setosa?

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.33,
                                                    random_state=42)

# %%
import tensorflow as tf

feature_columns = tf.contrib.learn.infer_real_valued_columns_from_input(X_train)
dnn_clf = tf.contrib.learn.DNNClassifier(hidden_units=[300,100],
                                         n_classes=10, 
                                         feature_columns=feature_columns)
dnn_clf.fit(x=X_train, y=y_train, batch_size=50, steps=40000)
# Out:
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpm4ddjuee
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fcdec24ab70>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_eval_distribute': None, '_experimental_max_worker_delay_secs': None, '_device_fn': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_protocol': None, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/tmp/tmpm4ddjuee'}
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpm4ddjuee/model.ckpt.
# INFO:tensorflow:loss = 2.5177877, step = 1
# INFO:tensorflow:global_step/sec: 383.473
# INFO:tensorflow:loss = 0.026061697, step = 101 (0.262 sec)
# INFO:tensorflow:global_step/sec: 634.267
# INFO:tensorflow:loss = 0.0054563163, step = 201 (0.158 sec)
# INFO:tensorflow:global_step/sec: 525.41
# INFO:tensorflow:loss = 0.0033972305, step = 301 (0.190 sec)
# INFO:tensorflow:global_step/sec: 472.285
# INFO:tensorflow:loss = 0.0029219305, step = 401 (0.212 sec)
# INFO:tensorflow:global_step/sec: 583.979
# INFO:tensorflow:loss = 0.0016177142, step = 501 (0.171 sec)
# INFO:tensorflow:global_step/sec: 499.227
# INFO:tensorflow:loss = 0.0010539037, step = 601 (0.200 sec)
# INFO:tensorflow:global_step/sec: 698.651
# INFO:tensorflow:loss = 0.00086742314, step = 701 (0.143 sec)
# INFO:tensorflow:global_step/sec: 603.008
# INFO:tensorflow:loss = 0.00090119475, step = 801 (0.167 sec)
# INFO:tensorflow:global_step/sec: 600.16
# INFO:tensorflow:loss = 0.00083744765, step = 901 (0.166 sec)
# INFO:tensorflow:global_step/sec: 520.125
# INFO:tensorflow:loss = 0.00038363348, step = 1001 (0.193 sec)
# INFO:tensorflow:global_step/sec: 412.271
# INFO:tensorflow:loss = 0.00069366745, step = 1101 (0.243 sec)
# INFO:tensorflow:global_step/sec: 450.507
# INFO:tensorflow:loss = 0.0002680778, step = 1201 (0.221 sec)
# INFO:tensorflow:global_step/sec: 461.103
# INFO:tensorflow:loss = 0.0003613548, step = 1301 (0.217 sec)
# INFO:tensorflow:global_step/sec: 419.097
# INFO:tensorflow:loss = 0.0004217365, step = 1401 (0.238 sec)
# INFO:tensorflow:global_step/sec: 499.033
# INFO:tensorflow:loss = 0.0004709452, step = 1501 (0.200 sec)
# INFO:tensorflow:global_step/sec: 449.295
# INFO:tensorflow:loss = 0.00032547853, step = 1601 (0.223 sec)
# INFO:tensorflow:global_step/sec: 418.654
# INFO:tensorflow:loss = 0.00034280214, step = 1701 (0.240 sec)
# INFO:tensorflow:global_step/sec: 422.077
# INFO:tensorflow:loss = 0.0004157977, step = 1801 (0.237 sec)
# INFO:tensorflow:global_step/sec: 428.179
# INFO:tensorflow:loss = 0.00044605785, step = 1901 (0.233 sec)
# INFO:tensorflow:global_step/sec: 479.25
# INFO:tensorflow:loss = 0.00027811032, step = 2001 (0.211 sec)
# INFO:tensorflow:global_step/sec: 451.45
# INFO:tensorflow:loss = 0.00027083236, step = 2101 (0.219 sec)
# INFO:tensorflow:global_step/sec: 464.55
# INFO:tensorflow:loss = 0.00025565393, step = 2201 (0.216 sec)
# INFO:tensorflow:global_step/sec: 458.181
# INFO:tensorflow:loss = 0.00010143204, step = 2301 (0.220 sec)
# INFO:tensorflow:global_step/sec: 478.904
# INFO:tensorflow:loss = 0.00016163893, step = 2401 (0.207 sec)
# INFO:tensorflow:global_step/sec: 570.463
# INFO:tensorflow:loss = 0.00016990563, step = 2501 (0.175 sec)
# INFO:tensorflow:global_step/sec: 531.998
# INFO:tensorflow:loss = 0.00017917856, step = 2601 (0.188 sec)
# INFO:tensorflow:global_step/sec: 536.854
# INFO:tensorflow:loss = 0.0002157066, step = 2701 (0.186 sec)
# INFO:tensorflow:global_step/sec: 554.304
# INFO:tensorflow:loss = 9.790048e-05, step = 2801 (0.181 sec)
# INFO:tensorflow:global_step/sec: 548.983
# INFO:tensorflow:loss = 0.00013424046, step = 2901 (0.183 sec)
# INFO:tensorflow:global_step/sec: 606.623
# INFO:tensorflow:loss = 8.871915e-05, step = 3001 (0.164 sec)
# INFO:tensorflow:global_step/sec: 526.116
# INFO:tensorflow:loss = 0.00014078488, step = 3101 (0.190 sec)
# INFO:tensorflow:global_step/sec: 516.665
# INFO:tensorflow:loss = 0.00017638117, step = 3201 (0.194 sec)
# INFO:tensorflow:global_step/sec: 511.995
# INFO:tensorflow:loss = 0.00010454832, step = 3301 (0.195 sec)
# INFO:tensorflow:global_step/sec: 465.773
# INFO:tensorflow:loss = 0.0001516798, step = 3401 (0.215 sec)
# INFO:tensorflow:global_step/sec: 428.481
# INFO:tensorflow:loss = 0.00015523605, step = 3501 (0.234 sec)
# INFO:tensorflow:global_step/sec: 431.608
# INFO:tensorflow:loss = 0.00017665813, step = 3601 (0.232 sec)
# INFO:tensorflow:global_step/sec: 429.595
# INFO:tensorflow:loss = 9.261394e-05, step = 3701 (0.232 sec)
# INFO:tensorflow:global_step/sec: 425.597
# INFO:tensorflow:loss = 0.00012987336, step = 3801 (0.235 sec)
# INFO:tensorflow:global_step/sec: 411.416
# INFO:tensorflow:loss = 0.000121474295, step = 3901 (0.245 sec)
# INFO:tensorflow:global_step/sec: 417.422
# INFO:tensorflow:loss = 0.00014063282, step = 4001 (0.238 sec)
# INFO:tensorflow:global_step/sec: 404.275
# INFO:tensorflow:loss = 0.00014913327, step = 4101 (0.250 sec)
# INFO:tensorflow:global_step/sec: 434.163
# INFO:tensorflow:loss = 0.00016030385, step = 4201 (0.228 sec)
# INFO:tensorflow:global_step/sec: 461.437
# INFO:tensorflow:loss = 0.00011093968, step = 4301 (0.217 sec)
# INFO:tensorflow:global_step/sec: 420.887
# INFO:tensorflow:loss = 2.1354057e-05, step = 4401 (0.237 sec)
# INFO:tensorflow:global_step/sec: 418.643
# INFO:tensorflow:loss = 0.00014272728, step = 4501 (0.239 sec)
# INFO:tensorflow:global_step/sec: 431.44
# INFO:tensorflow:loss = 0.00011608089, step = 4601 (0.232 sec)
# INFO:tensorflow:global_step/sec: 485.474
# INFO:tensorflow:loss = 7.284462e-05, step = 4701 (0.205 sec)
# INFO:tensorflow:global_step/sec: 445.983
# INFO:tensorflow:loss = 8.177402e-05, step = 4801 (0.224 sec)
# INFO:tensorflow:global_step/sec: 465.798
# INFO:tensorflow:loss = 9.977972e-05, step = 4901 (0.215 sec)
# INFO:tensorflow:global_step/sec: 453.11
# INFO:tensorflow:loss = 6.0821152e-05, step = 5001 (0.222 sec)
# INFO:tensorflow:global_step/sec: 483.287
# INFO:tensorflow:loss = 8.420143e-05, step = 5101 (0.207 sec)
# INFO:tensorflow:global_step/sec: 481.5
# INFO:tensorflow:loss = 8.2971696e-05, step = 5201 (0.207 sec)
# INFO:tensorflow:global_step/sec: 510.333
# INFO:tensorflow:loss = 7.092328e-05, step = 5301 (0.196 sec)
# INFO:tensorflow:global_step/sec: 467.772
# INFO:tensorflow:loss = 5.8643705e-05, step = 5401 (0.214 sec)
# INFO:tensorflow:global_step/sec: 494.089
# INFO:tensorflow:loss = 7.619372e-05, step = 5501 (0.202 sec)
# INFO:tensorflow:global_step/sec: 473.635
# INFO:tensorflow:loss = 7.7144854e-05, step = 5601 (0.212 sec)
# INFO:tensorflow:global_step/sec: 465.299
# INFO:tensorflow:loss = 7.411247e-05, step = 5701 (0.214 sec)
# INFO:tensorflow:global_step/sec: 468.452
# INFO:tensorflow:loss = 7.4326796e-05, step = 5801 (0.216 sec)
# INFO:tensorflow:global_step/sec: 483.533
# INFO:tensorflow:loss = 5.2949796e-05, step = 5901 (0.204 sec)
# INFO:tensorflow:global_step/sec: 510.555
# INFO:tensorflow:loss = 3.2308482e-05, step = 6001 (0.196 sec)
# INFO:tensorflow:global_step/sec: 469.535
# INFO:tensorflow:loss = 5.056024e-05, step = 6101 (0.213 sec)
# INFO:tensorflow:global_step/sec: 457.225
# INFO:tensorflow:loss = 5.2054784e-05, step = 6201 (0.219 sec)
# INFO:tensorflow:global_step/sec: 414.577
# INFO:tensorflow:loss = 8.676514e-05, step = 6301 (0.240 sec)
# INFO:tensorflow:global_step/sec: 430.657
# INFO:tensorflow:loss = 5.6466033e-05, step = 6401 (0.232 sec)
# INFO:tensorflow:global_step/sec: 512.203
# INFO:tensorflow:loss = 4.3714812e-05, step = 6501 (0.196 sec)
# INFO:tensorflow:global_step/sec: 416.103
# INFO:tensorflow:loss = 4.9198476e-05, step = 6601 (0.240 sec)
# INFO:tensorflow:global_step/sec: 498.614
# INFO:tensorflow:loss = 4.6157307e-05, step = 6701 (0.201 sec)
# INFO:tensorflow:global_step/sec: 421.756
# INFO:tensorflow:loss = 6.083028e-05, step = 6801 (0.239 sec)
# INFO:tensorflow:global_step/sec: 433.376
# INFO:tensorflow:loss = 6.901702e-05, step = 6901 (0.229 sec)
# INFO:tensorflow:global_step/sec: 386.096
# INFO:tensorflow:loss = 4.332005e-05, step = 7001 (0.260 sec)
# INFO:tensorflow:global_step/sec: 449.935
# INFO:tensorflow:loss = 8.935858e-05, step = 7101 (0.220 sec)
# INFO:tensorflow:global_step/sec: 495.183
# INFO:tensorflow:loss = 7.238131e-05, step = 7201 (0.202 sec)
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 7262 vs previous value: 7262. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# INFO:tensorflow:global_step/sec: 426.195
# INFO:tensorflow:loss = 3.9033064e-05, step = 7301 (0.234 sec)
# INFO:tensorflow:global_step/sec: 605.118
# INFO:tensorflow:loss = 7.784444e-05, step = 7401 (0.166 sec)
# INFO:tensorflow:global_step/sec: 452.214
# INFO:tensorflow:loss = 4.179583e-05, step = 7501 (0.221 sec)
# INFO:tensorflow:global_step/sec: 468.644
# INFO:tensorflow:loss = 4.0688003e-05, step = 7601 (0.213 sec)
# INFO:tensorflow:global_step/sec: 482.256
# INFO:tensorflow:loss = 4.858956e-05, step = 7701 (0.207 sec)
# INFO:tensorflow:global_step/sec: 437.71
# INFO:tensorflow:loss = 5.5314104e-05, step = 7801 (0.228 sec)
# INFO:tensorflow:global_step/sec: 473.508
# INFO:tensorflow:loss = 6.665034e-05, step = 7901 (0.212 sec)
# INFO:tensorflow:global_step/sec: 435.083
# INFO:tensorflow:loss = 6.563306e-05, step = 8001 (0.230 sec)
# INFO:tensorflow:global_step/sec: 477.668
# INFO:tensorflow:loss = 5.1790783e-05, step = 8101 (0.209 sec)
# INFO:tensorflow:global_step/sec: 485.65
# INFO:tensorflow:loss = 1.1774907e-05, step = 8201 (0.206 sec)
# INFO:tensorflow:global_step/sec: 422.916
# INFO:tensorflow:loss = 3.8657286e-05, step = 8301 (0.236 sec)
# INFO:tensorflow:global_step/sec: 455.467
# INFO:tensorflow:loss = 5.617132e-05, step = 8401 (0.219 sec)
# INFO:tensorflow:global_step/sec: 503.336
# INFO:tensorflow:loss = 2.1274645e-05, step = 8501 (0.198 sec)
# INFO:tensorflow:global_step/sec: 438.724
# INFO:tensorflow:loss = 3.2929274e-05, step = 8601 (0.228 sec)
# INFO:tensorflow:global_step/sec: 459.222
# INFO:tensorflow:loss = 2.9220571e-05, step = 8701 (0.218 sec)
# INFO:tensorflow:global_step/sec: 548.867
# INFO:tensorflow:loss = 3.0357132e-05, step = 8801 (0.182 sec)
# INFO:tensorflow:global_step/sec: 556.255
# INFO:tensorflow:loss = 3.9506576e-05, step = 8901 (0.180 sec)
# INFO:tensorflow:global_step/sec: 485.205
# INFO:tensorflow:loss = 3.5833495e-05, step = 9001 (0.206 sec)
# INFO:tensorflow:global_step/sec: 514.424
# INFO:tensorflow:loss = 2.8655239e-05, step = 9101 (0.194 sec)
# INFO:tensorflow:global_step/sec: 484.983
# INFO:tensorflow:loss = 2.2526505e-05, step = 9201 (0.206 sec)
# INFO:tensorflow:global_step/sec: 510.482
# INFO:tensorflow:loss = 3.707097e-05, step = 9301 (0.196 sec)
# INFO:tensorflow:global_step/sec: 547.131
# INFO:tensorflow:loss = 2.9533223e-05, step = 9401 (0.183 sec)
# INFO:tensorflow:global_step/sec: 481.526
# INFO:tensorflow:loss = 4.205008e-05, step = 9501 (0.208 sec)
# INFO:tensorflow:global_step/sec: 440.8
# INFO:tensorflow:loss = 3.097747e-05, step = 9601 (0.227 sec)
# INFO:tensorflow:global_step/sec: 438.29
# INFO:tensorflow:loss = 1.971828e-05, step = 9701 (0.228 sec)
# INFO:tensorflow:global_step/sec: 477.635
# INFO:tensorflow:loss = 5.0299073e-05, step = 9801 (0.210 sec)
# INFO:tensorflow:global_step/sec: 453.561
# INFO:tensorflow:loss = 2.2800348e-05, step = 9901 (0.220 sec)
# INFO:tensorflow:global_step/sec: 463.938
# INFO:tensorflow:loss = 6.1332204e-05, step = 10001 (0.215 sec)
# INFO:tensorflow:global_step/sec: 454.206
# INFO:tensorflow:loss = 2.8617686e-05, step = 10101 (0.220 sec)
# INFO:tensorflow:global_step/sec: 483.76
# INFO:tensorflow:loss = 5.8263136e-05, step = 10201 (0.207 sec)
# INFO:tensorflow:global_step/sec: 512.621
# INFO:tensorflow:loss = 5.5219498e-05, step = 10301 (0.195 sec)
# INFO:tensorflow:global_step/sec: 472.168
# INFO:tensorflow:loss = 4.3850458e-05, step = 10401 (0.212 sec)
# INFO:tensorflow:global_step/sec: 466.408
# INFO:tensorflow:loss = 3.731507e-05, step = 10501 (0.215 sec)
# INFO:tensorflow:global_step/sec: 464.404
# INFO:tensorflow:loss = 3.0745738e-05, step = 10601 (0.215 sec)
# INFO:tensorflow:global_step/sec: 437.017
# INFO:tensorflow:loss = 3.2757296e-05, step = 10701 (0.229 sec)
# INFO:tensorflow:global_step/sec: 461.014
# INFO:tensorflow:loss = 3.456923e-05, step = 10801 (0.217 sec)
# INFO:tensorflow:global_step/sec: 415.759
# INFO:tensorflow:loss = 1.40681395e-05, step = 10901 (0.241 sec)
# INFO:tensorflow:global_step/sec: 423.348
# INFO:tensorflow:loss = 3.866014e-05, step = 11001 (0.236 sec)
# INFO:tensorflow:global_step/sec: 417.362
# INFO:tensorflow:loss = 2.9885245e-05, step = 11101 (0.240 sec)
# INFO:tensorflow:global_step/sec: 468.318
# INFO:tensorflow:loss = 4.3265292e-05, step = 11201 (0.214 sec)
# INFO:tensorflow:global_step/sec: 441.597
# INFO:tensorflow:loss = 1.4506524e-05, step = 11301 (0.226 sec)
# INFO:tensorflow:global_step/sec: 447.667
# INFO:tensorflow:loss = 4.1538995e-05, step = 11401 (0.223 sec)
# INFO:tensorflow:global_step/sec: 444.842
# INFO:tensorflow:loss = 3.85533e-05, step = 11501 (0.226 sec)
# INFO:tensorflow:global_step/sec: 527.743
# INFO:tensorflow:loss = 4.37017e-05, step = 11601 (0.189 sec)
# INFO:tensorflow:global_step/sec: 486.079
# INFO:tensorflow:loss = 3.3137352e-05, step = 11701 (0.205 sec)
# INFO:tensorflow:global_step/sec: 424.587
# INFO:tensorflow:loss = 1.8086552e-05, step = 11801 (0.237 sec)
# INFO:tensorflow:global_step/sec: 426.091
# INFO:tensorflow:loss = 3.9598377e-05, step = 11901 (0.233 sec)
# INFO:tensorflow:global_step/sec: 470.877
# INFO:tensorflow:loss = 4.5487774e-05, step = 12001 (0.213 sec)
# INFO:tensorflow:global_step/sec: 454.007
# INFO:tensorflow:loss = 3.589885e-05, step = 12101 (0.221 sec)
# INFO:tensorflow:global_step/sec: 439.359
# INFO:tensorflow:loss = 4.0748826e-05, step = 12201 (0.228 sec)
# INFO:tensorflow:global_step/sec: 422.084
# INFO:tensorflow:loss = 3.0463098e-05, step = 12301 (0.237 sec)
# INFO:tensorflow:global_step/sec: 400.606
# INFO:tensorflow:loss = 3.1618358e-05, step = 12401 (0.249 sec)
# INFO:tensorflow:global_step/sec: 415.109
# INFO:tensorflow:loss = 3.193422e-05, step = 12501 (0.242 sec)
# INFO:tensorflow:global_step/sec: 443.869
# INFO:tensorflow:loss = 2.7435874e-05, step = 12601 (0.224 sec)
# INFO:tensorflow:global_step/sec: 429.119
# INFO:tensorflow:loss = 3.2451004e-05, step = 12701 (0.233 sec)
# INFO:tensorflow:global_step/sec: 415.975
# INFO:tensorflow:loss = 1.7309681e-05, step = 12801 (0.240 sec)
# INFO:tensorflow:global_step/sec: 421.547
# INFO:tensorflow:loss = 2.548079e-05, step = 12901 (0.238 sec)
# INFO:tensorflow:global_step/sec: 419.304
# INFO:tensorflow:loss = 1.8187024e-05, step = 13001 (0.238 sec)
# INFO:tensorflow:global_step/sec: 418.284
# INFO:tensorflow:loss = 2.2865497e-05, step = 13101 (0.239 sec)
# INFO:tensorflow:global_step/sec: 420.42
# INFO:tensorflow:loss = 3.1838605e-05, step = 13201 (0.238 sec)
# INFO:tensorflow:global_step/sec: 431.698
# INFO:tensorflow:loss = 1.5304482e-05, step = 13301 (0.232 sec)
# INFO:tensorflow:global_step/sec: 439.337
# INFO:tensorflow:loss = 3.2198823e-05, step = 13401 (0.228 sec)
# INFO:tensorflow:global_step/sec: 446.823
# INFO:tensorflow:loss = 1.7645758e-05, step = 13501 (0.223 sec)
# INFO:tensorflow:global_step/sec: 425.225
# INFO:tensorflow:loss = 2.7110153e-05, step = 13601 (0.235 sec)
# INFO:tensorflow:global_step/sec: 418.111
# INFO:tensorflow:loss = 2.4904904e-05, step = 13701 (0.239 sec)
# INFO:tensorflow:global_step/sec: 420.103
# INFO:tensorflow:loss = 2.8189574e-05, step = 13801 (0.238 sec)
# INFO:tensorflow:global_step/sec: 414.684
# INFO:tensorflow:loss = 2.3519166e-05, step = 13901 (0.241 sec)
# INFO:tensorflow:global_step/sec: 426.483
# INFO:tensorflow:loss = 2.034051e-05, step = 14001 (0.235 sec)
# INFO:tensorflow:global_step/sec: 418.862
# INFO:tensorflow:loss = 2.7508484e-05, step = 14101 (0.239 sec)
# INFO:tensorflow:global_step/sec: 452.961
# INFO:tensorflow:loss = 1.5035381e-05, step = 14201 (0.221 sec)
# INFO:tensorflow:global_step/sec: 425.353
# INFO:tensorflow:loss = 1.9037425e-05, step = 14301 (0.235 sec)
# INFO:tensorflow:global_step/sec: 450.855
# INFO:tensorflow:loss = 3.7153495e-05, step = 14401 (0.222 sec)
# INFO:tensorflow:global_step/sec: 436.712
# INFO:tensorflow:loss = 1.1943605e-05, step = 14501 (0.228 sec)
# INFO:tensorflow:global_step/sec: 442.327
# INFO:tensorflow:loss = 3.278858e-05, step = 14601 (0.226 sec)
# INFO:tensorflow:global_step/sec: 428.112
# INFO:tensorflow:loss = 1.9164525e-05, step = 14701 (0.233 sec)
# INFO:tensorflow:global_step/sec: 442.679
# INFO:tensorflow:loss = 1.2363733e-05, step = 14801 (0.226 sec)
# INFO:tensorflow:global_step/sec: 445.973
# INFO:tensorflow:loss = 2.4470028e-05, step = 14901 (0.224 sec)
# INFO:tensorflow:global_step/sec: 428.957
# INFO:tensorflow:loss = 2.1035921e-05, step = 15001 (0.233 sec)
# INFO:tensorflow:global_step/sec: 455.754
# INFO:tensorflow:loss = 2.2732862e-05, step = 15101 (0.220 sec)
# INFO:tensorflow:global_step/sec: 438.103
# INFO:tensorflow:loss = 1.7674563e-05, step = 15201 (0.228 sec)
# INFO:tensorflow:global_step/sec: 449.529
# INFO:tensorflow:loss = 2.2717508e-05, step = 15301 (0.223 sec)
# INFO:tensorflow:global_step/sec: 639.481
# INFO:tensorflow:loss = 2.1714803e-05, step = 15401 (0.156 sec)
# INFO:tensorflow:global_step/sec: 624.305
# INFO:tensorflow:loss = 2.4737863e-05, step = 15501 (0.160 sec)
# INFO:tensorflow:global_step/sec: 622.39
# INFO:tensorflow:loss = 2.3798773e-05, step = 15601 (0.160 sec)
# INFO:tensorflow:global_step/sec: 689.293
# INFO:tensorflow:loss = 1.834812e-05, step = 15701 (0.145 sec)
# INFO:tensorflow:global_step/sec: 632.842
# INFO:tensorflow:loss = 2.6204221e-05, step = 15801 (0.158 sec)
# INFO:tensorflow:global_step/sec: 659.037
# INFO:tensorflow:loss = 3.1256375e-05, step = 15901 (0.152 sec)
# INFO:tensorflow:global_step/sec: 637.764
# INFO:tensorflow:loss = 2.52111e-05, step = 16001 (0.157 sec)
# INFO:tensorflow:global_step/sec: 549.636
# INFO:tensorflow:loss = 3.0164687e-05, step = 16101 (0.183 sec)
# INFO:tensorflow:global_step/sec: 658.966
# INFO:tensorflow:loss = 1.4849798e-05, step = 16201 (0.151 sec)
# INFO:tensorflow:global_step/sec: 701.922
# INFO:tensorflow:loss = 3.4806406e-05, step = 16301 (0.143 sec)
# INFO:tensorflow:global_step/sec: 630.016
# INFO:tensorflow:loss = 2.1919042e-05, step = 16401 (0.159 sec)
# INFO:tensorflow:global_step/sec: 606.652
# INFO:tensorflow:loss = 1.44303685e-05, step = 16501 (0.165 sec)
# INFO:tensorflow:global_step/sec: 579.05
# INFO:tensorflow:loss = 2.0921389e-05, step = 16601 (0.172 sec)
# INFO:tensorflow:global_step/sec: 542.216
# INFO:tensorflow:loss = 2.5268662e-05, step = 16701 (0.184 sec)
# INFO:tensorflow:global_step/sec: 635.752
# INFO:tensorflow:loss = 1.281635e-05, step = 16801 (0.157 sec)
# INFO:tensorflow:global_step/sec: 536.398
# INFO:tensorflow:loss = 1.6033595e-05, step = 16901 (0.190 sec)
# INFO:tensorflow:global_step/sec: 480.95
# INFO:tensorflow:loss = 5.8244545e-06, step = 17001 (0.205 sec)
# INFO:tensorflow:global_step/sec: 457.462
# INFO:tensorflow:loss = 1.6592561e-05, step = 17101 (0.218 sec)
# INFO:tensorflow:global_step/sec: 469.218
# INFO:tensorflow:loss = 9.960247e-06, step = 17201 (0.213 sec)
# INFO:tensorflow:global_step/sec: 489.499
# INFO:tensorflow:loss = 2.2555982e-05, step = 17301 (0.204 sec)
# INFO:tensorflow:global_step/sec: 499.668
# INFO:tensorflow:loss = 2.7373619e-05, step = 17401 (0.200 sec)
# INFO:tensorflow:global_step/sec: 470.614
# INFO:tensorflow:loss = 2.068451e-05, step = 17501 (0.213 sec)
# INFO:tensorflow:global_step/sec: 472.323
# INFO:tensorflow:loss = 1.957699e-05, step = 17601 (0.212 sec)
# INFO:tensorflow:global_step/sec: 475.642
# INFO:tensorflow:loss = 2.3480778e-05, step = 17701 (0.210 sec)
# INFO:tensorflow:global_step/sec: 416.19
# INFO:tensorflow:loss = 2.5037336e-05, step = 17801 (0.241 sec)
# INFO:tensorflow:global_step/sec: 438.076
# INFO:tensorflow:loss = 3.4780576e-05, step = 17901 (0.227 sec)
# INFO:tensorflow:global_step/sec: 449.567
# INFO:tensorflow:loss = 2.617242e-05, step = 18001 (0.222 sec)
# INFO:tensorflow:global_step/sec: 430.41
# INFO:tensorflow:loss = 1.996454e-05, step = 18101 (0.232 sec)
# INFO:tensorflow:global_step/sec: 432.681
# INFO:tensorflow:loss = 2.4355999e-05, step = 18201 (0.231 sec)
# INFO:tensorflow:global_step/sec: 543.785
# INFO:tensorflow:loss = 2.2778404e-05, step = 18301 (0.184 sec)
# INFO:tensorflow:global_step/sec: 441.498
# INFO:tensorflow:loss = 1.1623451e-05, step = 18401 (0.228 sec)
# INFO:tensorflow:global_step/sec: 420.021
# INFO:tensorflow:loss = 1.2093884e-05, step = 18501 (0.237 sec)
# INFO:tensorflow:global_step/sec: 425.448
# INFO:tensorflow:loss = 1.4206223e-05, step = 18601 (0.235 sec)
# INFO:tensorflow:global_step/sec: 466.876
# INFO:tensorflow:loss = 1.775811e-05, step = 18701 (0.214 sec)
# INFO:tensorflow:global_step/sec: 460.933
# INFO:tensorflow:loss = 2.6632491e-05, step = 18801 (0.218 sec)
# INFO:tensorflow:global_step/sec: 473.744
# INFO:tensorflow:loss = 9.147374e-06, step = 18901 (0.211 sec)
# INFO:tensorflow:global_step/sec: 432.139
# INFO:tensorflow:loss = 1.858535e-05, step = 19001 (0.231 sec)
# INFO:tensorflow:global_step/sec: 449.456
# INFO:tensorflow:loss = 1.6890514e-05, step = 19101 (0.222 sec)
# INFO:tensorflow:global_step/sec: 446.875
# INFO:tensorflow:loss = 2.5405088e-05, step = 19201 (0.224 sec)
# INFO:tensorflow:global_step/sec: 499.774
# INFO:tensorflow:loss = 1.6821408e-05, step = 19301 (0.200 sec)
# INFO:tensorflow:global_step/sec: 589.759
# INFO:tensorflow:loss = 2.0846966e-05, step = 19401 (0.169 sec)
# INFO:tensorflow:global_step/sec: 626.151
# INFO:tensorflow:loss = 1.4858814e-05, step = 19501 (0.159 sec)
# INFO:tensorflow:global_step/sec: 745.897
# INFO:tensorflow:loss = 1.2413606e-05, step = 19601 (0.135 sec)
# INFO:tensorflow:global_step/sec: 672.996
# INFO:tensorflow:loss = 1.3822533e-05, step = 19701 (0.148 sec)
# INFO:tensorflow:global_step/sec: 695.765
# INFO:tensorflow:loss = 1.9523817e-05, step = 19801 (0.144 sec)
# INFO:tensorflow:global_step/sec: 556.489
# INFO:tensorflow:loss = 2.6091475e-05, step = 19901 (0.180 sec)
# INFO:tensorflow:global_step/sec: 461.425
# INFO:tensorflow:loss = 1.2487227e-05, step = 20001 (0.217 sec)
# INFO:tensorflow:global_step/sec: 578.201
# INFO:tensorflow:loss = 1.10736e-05, step = 20101 (0.172 sec)
# INFO:tensorflow:global_step/sec: 504.549
# INFO:tensorflow:loss = 2.1447973e-05, step = 20201 (0.199 sec)
# INFO:tensorflow:global_step/sec: 485.542
# INFO:tensorflow:loss = 2.3095063e-05, step = 20301 (0.206 sec)
# INFO:tensorflow:global_step/sec: 453.139
# INFO:tensorflow:loss = 2.1703663e-05, step = 20401 (0.221 sec)
# INFO:tensorflow:global_step/sec: 444.606
# INFO:tensorflow:loss = 1.1824788e-05, step = 20501 (0.225 sec)
# INFO:tensorflow:global_step/sec: 477.028
# INFO:tensorflow:loss = 1.0716263e-05, step = 20601 (0.209 sec)
# INFO:tensorflow:global_step/sec: 469.146
# INFO:tensorflow:loss = 1.4968632e-05, step = 20701 (0.213 sec)
# INFO:tensorflow:global_step/sec: 461.551
# INFO:tensorflow:loss = 2.1164436e-05, step = 20801 (0.217 sec)
# INFO:tensorflow:global_step/sec: 445.924
# INFO:tensorflow:loss = 1.5720008e-05, step = 20901 (0.224 sec)
# INFO:tensorflow:global_step/sec: 441.592
# INFO:tensorflow:loss = 1.3852963e-05, step = 21001 (0.226 sec)
# INFO:tensorflow:global_step/sec: 436.158
# INFO:tensorflow:loss = 2.1860302e-05, step = 21101 (0.230 sec)
# INFO:tensorflow:global_step/sec: 435.894
# INFO:tensorflow:loss = 1.02821805e-05, step = 21201 (0.230 sec)
# INFO:tensorflow:global_step/sec: 459.319
# INFO:tensorflow:loss = 1.4017794e-05, step = 21301 (0.216 sec)
# INFO:tensorflow:global_step/sec: 431.298
# INFO:tensorflow:loss = 1.4139278e-05, step = 21401 (0.232 sec)
# INFO:tensorflow:global_step/sec: 434.828
# INFO:tensorflow:loss = 9.023502e-06, step = 21501 (0.230 sec)
# INFO:tensorflow:global_step/sec: 430.177
# INFO:tensorflow:loss = 1.9977166e-05, step = 21601 (0.232 sec)
# INFO:tensorflow:global_step/sec: 442.333
# INFO:tensorflow:loss = 2.6099111e-05, step = 21701 (0.226 sec)
# INFO:tensorflow:global_step/sec: 446.303
# INFO:tensorflow:loss = 8.542082e-06, step = 21801 (0.224 sec)
# INFO:tensorflow:global_step/sec: 438.666
# INFO:tensorflow:loss = 1.0759267e-05, step = 21901 (0.228 sec)
# INFO:tensorflow:global_step/sec: 448.377
# INFO:tensorflow:loss = 2.1362428e-05, step = 22001 (0.223 sec)
# INFO:tensorflow:global_step/sec: 479.529
# INFO:tensorflow:loss = 7.0448605e-06, step = 22101 (0.208 sec)
# INFO:tensorflow:global_step/sec: 482.244
# INFO:tensorflow:loss = 1.5531661e-05, step = 22201 (0.208 sec)
# INFO:tensorflow:global_step/sec: 445.656
# INFO:tensorflow:loss = 1.5092825e-05, step = 22301 (0.225 sec)
# INFO:tensorflow:global_step/sec: 448.001
# INFO:tensorflow:loss = 2.3319828e-05, step = 22401 (0.223 sec)
# INFO:tensorflow:global_step/sec: 427.877
# INFO:tensorflow:loss = 1.41868695e-05, step = 22501 (0.234 sec)
# INFO:tensorflow:global_step/sec: 445.065
# INFO:tensorflow:loss = 1.262058e-05, step = 22601 (0.225 sec)
# INFO:tensorflow:global_step/sec: 446.309
# INFO:tensorflow:loss = 1.12214075e-05, step = 22701 (0.225 sec)
# INFO:tensorflow:global_step/sec: 441.881
# INFO:tensorflow:loss = 1.7300543e-05, step = 22801 (0.225 sec)
# INFO:tensorflow:global_step/sec: 435.1
# INFO:tensorflow:loss = 2.1164531e-05, step = 22901 (0.230 sec)
# INFO:tensorflow:global_step/sec: 501.797
# INFO:tensorflow:loss = 1.8883127e-05, step = 23001 (0.199 sec)
# INFO:tensorflow:global_step/sec: 459.144
# INFO:tensorflow:loss = 2.4878787e-05, step = 23101 (0.218 sec)
# INFO:tensorflow:global_step/sec: 488.18
# INFO:tensorflow:loss = 1.933852e-05, step = 23201 (0.205 sec)
# INFO:tensorflow:global_step/sec: 502.671
# INFO:tensorflow:loss = 4.167446e-06, step = 23301 (0.199 sec)
# INFO:tensorflow:global_step/sec: 541.949
# INFO:tensorflow:loss = 7.955562e-06, step = 23401 (0.185 sec)
# INFO:tensorflow:global_step/sec: 513.852
# INFO:tensorflow:loss = 1.4587871e-05, step = 23501 (0.194 sec)
# INFO:tensorflow:global_step/sec: 485.135
# INFO:tensorflow:loss = 1.5869618e-05, step = 23601 (0.206 sec)
# INFO:tensorflow:global_step/sec: 473.775
# INFO:tensorflow:loss = 9.271578e-06, step = 23701 (0.211 sec)
# INFO:tensorflow:global_step/sec: 493.156
# INFO:tensorflow:loss = 1.8654267e-05, step = 23801 (0.203 sec)
# INFO:tensorflow:global_step/sec: 552.496
# INFO:tensorflow:loss = 4.0935424e-06, step = 23901 (0.181 sec)
# INFO:tensorflow:global_step/sec: 631.163
# INFO:tensorflow:loss = 1.9936904e-05, step = 24001 (0.159 sec)
# INFO:tensorflow:global_step/sec: 491.506
# INFO:tensorflow:loss = 1.0632936e-05, step = 24101 (0.204 sec)
# INFO:tensorflow:global_step/sec: 531.546
# INFO:tensorflow:loss = 1.1886242e-05, step = 24201 (0.188 sec)
# INFO:tensorflow:global_step/sec: 624.636
# INFO:tensorflow:loss = 1.5000205e-05, step = 24301 (0.160 sec)
# INFO:tensorflow:global_step/sec: 526.52
# INFO:tensorflow:loss = 1.594623e-05, step = 24401 (0.190 sec)
# INFO:tensorflow:global_step/sec: 490.5
# INFO:tensorflow:loss = 9.846072e-06, step = 24501 (0.205 sec)
# INFO:tensorflow:global_step/sec: 514.683
# INFO:tensorflow:loss = 1.2918738e-05, step = 24601 (0.192 sec)
# INFO:tensorflow:global_step/sec: 517.151
# INFO:tensorflow:loss = 1.919555e-05, step = 24701 (0.193 sec)
# INFO:tensorflow:global_step/sec: 450.724
# INFO:tensorflow:loss = 1.0725594e-05, step = 24801 (0.222 sec)
# INFO:tensorflow:global_step/sec: 458.514
# INFO:tensorflow:loss = 1.5450496e-05, step = 24901 (0.218 sec)
# INFO:tensorflow:global_step/sec: 444.354
# INFO:tensorflow:loss = 2.2044416e-05, step = 25001 (0.225 sec)
# INFO:tensorflow:global_step/sec: 501.602
# INFO:tensorflow:loss = 1.7563012e-05, step = 25101 (0.199 sec)
# INFO:tensorflow:global_step/sec: 508.441
# INFO:tensorflow:loss = 1.8637802e-05, step = 25201 (0.197 sec)
# INFO:tensorflow:global_step/sec: 549.94
# INFO:tensorflow:loss = 1.8130093e-05, step = 25301 (0.182 sec)
# INFO:tensorflow:global_step/sec: 563.45
# INFO:tensorflow:loss = 9.137614e-06, step = 25401 (0.178 sec)
# INFO:tensorflow:global_step/sec: 441.965
# INFO:tensorflow:loss = 9.669293e-06, step = 25501 (0.226 sec)
# INFO:tensorflow:global_step/sec: 417.755
# INFO:tensorflow:loss = 1.24348535e-05, step = 25601 (0.240 sec)
# INFO:tensorflow:global_step/sec: 449.714
# INFO:tensorflow:loss = 9.9220315e-06, step = 25701 (0.223 sec)
# INFO:tensorflow:global_step/sec: 497.378
# INFO:tensorflow:loss = 1.1753175e-05, step = 25801 (0.200 sec)
# INFO:tensorflow:global_step/sec: 445.599
# INFO:tensorflow:loss = 1.8678391e-05, step = 25901 (0.224 sec)
# INFO:tensorflow:global_step/sec: 423.995
# INFO:tensorflow:loss = 6.70397e-06, step = 26001 (0.236 sec)
# INFO:tensorflow:global_step/sec: 464.688
# INFO:tensorflow:loss = 1.703348e-05, step = 26101 (0.215 sec)
# INFO:tensorflow:global_step/sec: 432.784
# INFO:tensorflow:loss = 3.9266697e-06, step = 26201 (0.231 sec)
# INFO:tensorflow:global_step/sec: 431.666
# INFO:tensorflow:loss = 5.33077e-06, step = 26301 (0.231 sec)
# INFO:tensorflow:global_step/sec: 429.799
# INFO:tensorflow:loss = 1.3762885e-05, step = 26401 (0.233 sec)
# INFO:tensorflow:global_step/sec: 430.673
# INFO:tensorflow:loss = 1.9067078e-05, step = 26501 (0.232 sec)
# INFO:tensorflow:global_step/sec: 446.45
# INFO:tensorflow:loss = 2.2290194e-05, step = 26601 (0.225 sec)
# INFO:tensorflow:global_step/sec: 455.371
# INFO:tensorflow:loss = 1.1362231e-05, step = 26701 (0.219 sec)
# INFO:tensorflow:global_step/sec: 438.951
# INFO:tensorflow:loss = 9.962945e-06, step = 26801 (0.228 sec)
# INFO:tensorflow:global_step/sec: 453.021
# INFO:tensorflow:loss = 8.515918e-06, step = 26901 (0.221 sec)
# INFO:tensorflow:global_step/sec: 547.156
# INFO:tensorflow:loss = 7.4955433e-06, step = 27001 (0.183 sec)
# INFO:tensorflow:global_step/sec: 553.522
# INFO:tensorflow:loss = 1.7383927e-05, step = 27101 (0.180 sec)
# INFO:tensorflow:global_step/sec: 573.862
# INFO:tensorflow:loss = 1.4773594e-05, step = 27201 (0.175 sec)
# INFO:tensorflow:global_step/sec: 578.206
# INFO:tensorflow:loss = 1.2256035e-05, step = 27301 (0.174 sec)
# INFO:tensorflow:global_step/sec: 519.763
# INFO:tensorflow:loss = 1.04944365e-05, step = 27401 (0.191 sec)
# INFO:tensorflow:global_step/sec: 496.329
# INFO:tensorflow:loss = 1.9558125e-05, step = 27501 (0.202 sec)
# INFO:tensorflow:global_step/sec: 472.932
# INFO:tensorflow:loss = 1.0775823e-05, step = 27601 (0.211 sec)
# INFO:tensorflow:global_step/sec: 446.603
# INFO:tensorflow:loss = 7.862665e-06, step = 27701 (0.224 sec)
# INFO:tensorflow:global_step/sec: 464.911
# INFO:tensorflow:loss = 7.58365e-06, step = 27801 (0.215 sec)
# INFO:tensorflow:global_step/sec: 443.095
# INFO:tensorflow:loss = 7.679021e-06, step = 27901 (0.226 sec)
# INFO:tensorflow:global_step/sec: 424.502
# INFO:tensorflow:loss = 1.4363352e-05, step = 28001 (0.236 sec)
# INFO:tensorflow:global_step/sec: 445.572
# INFO:tensorflow:loss = 7.724411e-06, step = 28101 (0.224 sec)
# INFO:tensorflow:global_step/sec: 438.604
# INFO:tensorflow:loss = 1.3810662e-05, step = 28201 (0.228 sec)
# INFO:tensorflow:global_step/sec: 423.587
# INFO:tensorflow:loss = 1.5093075e-05, step = 28301 (0.240 sec)
# INFO:tensorflow:global_step/sec: 415.174
# INFO:tensorflow:loss = 1.4225382e-05, step = 28401 (0.237 sec)
# INFO:tensorflow:global_step/sec: 420.36
# INFO:tensorflow:loss = 1.0511228e-05, step = 28501 (0.238 sec)
# INFO:tensorflow:global_step/sec: 418.576
# INFO:tensorflow:loss = 9.784072e-06, step = 28601 (0.239 sec)
# INFO:tensorflow:global_step/sec: 431.495
# INFO:tensorflow:loss = 5.0828107e-06, step = 28701 (0.231 sec)
# INFO:tensorflow:global_step/sec: 431.242
# INFO:tensorflow:loss = 1.4390008e-05, step = 28801 (0.232 sec)
# INFO:tensorflow:global_step/sec: 422.679
# INFO:tensorflow:loss = 9.202211e-06, step = 28901 (0.237 sec)
# INFO:tensorflow:global_step/sec: 420.641
# INFO:tensorflow:loss = 1.5700965e-05, step = 29001 (0.238 sec)
# INFO:tensorflow:global_step/sec: 409.51
# INFO:tensorflow:loss = 1.5343305e-05, step = 29101 (0.245 sec)
# INFO:tensorflow:global_step/sec: 419.448
# INFO:tensorflow:loss = 1.3159639e-05, step = 29201 (0.237 sec)
# INFO:tensorflow:global_step/sec: 448.451
# INFO:tensorflow:loss = 1.1347816e-05, step = 29301 (0.223 sec)
# INFO:tensorflow:global_step/sec: 465.435
# INFO:tensorflow:loss = 6.7564547e-06, step = 29401 (0.215 sec)
# INFO:tensorflow:global_step/sec: 418.058
# INFO:tensorflow:loss = 9.521854e-06, step = 29501 (0.239 sec)
# INFO:tensorflow:global_step/sec: 437.303
# INFO:tensorflow:loss = 6.8423005e-06, step = 29601 (0.229 sec)
# INFO:tensorflow:global_step/sec: 440.951
# INFO:tensorflow:loss = 8.7659155e-06, step = 29701 (0.226 sec)
# INFO:tensorflow:global_step/sec: 441.991
# INFO:tensorflow:loss = 7.39304e-06, step = 29801 (0.226 sec)
# INFO:tensorflow:global_step/sec: 467.184
# INFO:tensorflow:loss = 9.991183e-06, step = 29901 (0.216 sec)
# INFO:tensorflow:global_step/sec: 439.507
# INFO:tensorflow:loss = 6.4679834e-06, step = 30001 (0.226 sec)
# INFO:tensorflow:global_step/sec: 437.044
# INFO:tensorflow:loss = 1.08614495e-05, step = 30101 (0.229 sec)
# INFO:tensorflow:global_step/sec: 467.683
# INFO:tensorflow:loss = 1.6270846e-05, step = 30201 (0.214 sec)
# INFO:tensorflow:global_step/sec: 446.267
# INFO:tensorflow:loss = 8.093653e-06, step = 30301 (0.224 sec)
# INFO:tensorflow:global_step/sec: 450.616
# INFO:tensorflow:loss = 1.4451791e-05, step = 30401 (0.221 sec)
# INFO:tensorflow:global_step/sec: 489.727
# INFO:tensorflow:loss = 8.0031705e-06, step = 30501 (0.204 sec)
# INFO:tensorflow:global_step/sec: 480.538
# INFO:tensorflow:loss = 1.0871064e-05, step = 30601 (0.208 sec)
# INFO:tensorflow:global_step/sec: 462.654
# INFO:tensorflow:loss = 5.2950304e-06, step = 30701 (0.216 sec)
# INFO:tensorflow:global_step/sec: 455.243
# INFO:tensorflow:loss = 6.7418932e-06, step = 30801 (0.221 sec)
# INFO:tensorflow:global_step/sec: 459.625
# INFO:tensorflow:loss = 8.9068535e-06, step = 30901 (0.216 sec)
# INFO:tensorflow:global_step/sec: 475.395
# INFO:tensorflow:loss = 1.0241767e-05, step = 31001 (0.210 sec)
# INFO:tensorflow:global_step/sec: 486.962
# INFO:tensorflow:loss = 1.2163376e-05, step = 31101 (0.205 sec)
# INFO:tensorflow:global_step/sec: 422.393
# INFO:tensorflow:loss = 1.2585232e-05, step = 31201 (0.237 sec)
# INFO:tensorflow:global_step/sec: 454.27
# INFO:tensorflow:loss = 1.0718504e-05, step = 31301 (0.221 sec)
# INFO:tensorflow:global_step/sec: 462.853
# INFO:tensorflow:loss = 1.2125233e-05, step = 31401 (0.216 sec)
# INFO:tensorflow:global_step/sec: 414.642
# INFO:tensorflow:loss = 1.0590058e-05, step = 31501 (0.241 sec)
# INFO:tensorflow:global_step/sec: 415.143
# INFO:tensorflow:loss = 1.2344269e-05, step = 31601 (0.241 sec)
# INFO:tensorflow:global_step/sec: 407.543
# INFO:tensorflow:loss = 8.99976e-06, step = 31701 (0.246 sec)
# INFO:tensorflow:global_step/sec: 427.886
# INFO:tensorflow:loss = 1.1896206e-05, step = 31801 (0.233 sec)
# INFO:tensorflow:global_step/sec: 458.338
# INFO:tensorflow:loss = 2.1815122e-06, step = 31901 (0.218 sec)
# INFO:tensorflow:global_step/sec: 427.24
# INFO:tensorflow:loss = 1.6394813e-05, step = 32001 (0.234 sec)
# INFO:tensorflow:global_step/sec: 447.098
# INFO:tensorflow:loss = 3.3711476e-06, step = 32101 (0.225 sec)
# INFO:tensorflow:global_step/sec: 466.782
# INFO:tensorflow:loss = 1.14694985e-05, step = 32201 (0.213 sec)
# INFO:tensorflow:global_step/sec: 456.712
# INFO:tensorflow:loss = 5.0208114e-06, step = 32301 (0.219 sec)
# INFO:tensorflow:global_step/sec: 441.261
# INFO:tensorflow:loss = 1.3758093e-05, step = 32401 (0.226 sec)
# INFO:tensorflow:global_step/sec: 412.01
# INFO:tensorflow:loss = 1.0413297e-05, step = 32501 (0.244 sec)
# INFO:tensorflow:global_step/sec: 462.186
# INFO:tensorflow:loss = 7.0518663e-06, step = 32601 (0.216 sec)
# INFO:tensorflow:global_step/sec: 441.082
# INFO:tensorflow:loss = 1.15218045e-05, step = 32701 (0.226 sec)
# INFO:tensorflow:global_step/sec: 436.675
# INFO:tensorflow:loss = 6.9185535e-06, step = 32801 (0.229 sec)
# INFO:tensorflow:global_step/sec: 418.913
# INFO:tensorflow:loss = 9.907938e-06, step = 32901 (0.241 sec)
# INFO:tensorflow:global_step/sec: 458.67
# INFO:tensorflow:loss = 5.168717e-06, step = 33001 (0.216 sec)
# INFO:tensorflow:global_step/sec: 509.233
# INFO:tensorflow:loss = 1.2225152e-05, step = 33101 (0.197 sec)
# INFO:tensorflow:global_step/sec: 444.744
# INFO:tensorflow:loss = 1.2413801e-05, step = 33201 (0.225 sec)
# INFO:tensorflow:global_step/sec: 415.199
# INFO:tensorflow:loss = 8.081845e-06, step = 33301 (0.240 sec)
# INFO:tensorflow:global_step/sec: 436.12
# INFO:tensorflow:loss = 5.082892e-06, step = 33401 (0.229 sec)
# INFO:tensorflow:global_step/sec: 433.47
# INFO:tensorflow:loss = 5.180633e-06, step = 33501 (0.231 sec)
# INFO:tensorflow:global_step/sec: 465.508
# INFO:tensorflow:loss = 1.1254988e-05, step = 33601 (0.215 sec)
# INFO:tensorflow:global_step/sec: 421.958
# INFO:tensorflow:loss = 1.4733183e-05, step = 33701 (0.237 sec)
# INFO:tensorflow:global_step/sec: 418.143
# INFO:tensorflow:loss = 1.0225067e-05, step = 33801 (0.239 sec)
# INFO:tensorflow:global_step/sec: 410.898
# INFO:tensorflow:loss = 5.697977e-06, step = 33901 (0.243 sec)
# INFO:tensorflow:global_step/sec: 443.161
# INFO:tensorflow:loss = 1.1650817e-05, step = 34001 (0.226 sec)
# INFO:tensorflow:global_step/sec: 447.757
# INFO:tensorflow:loss = 9.245411e-06, step = 34101 (0.223 sec)
# INFO:tensorflow:global_step/sec: 424.972
# INFO:tensorflow:loss = 4.2819142e-06, step = 34201 (0.235 sec)
# INFO:tensorflow:global_step/sec: 423.795
# INFO:tensorflow:loss = 8.065341e-06, step = 34301 (0.236 sec)
# INFO:tensorflow:global_step/sec: 425.245
# INFO:tensorflow:loss = 9.13074e-06, step = 34401 (0.236 sec)
# INFO:tensorflow:global_step/sec: 465.932
# INFO:tensorflow:loss = 3.700202e-06, step = 34501 (0.215 sec)
# INFO:tensorflow:global_step/sec: 419.386
# INFO:tensorflow:loss = 6.5465124e-06, step = 34601 (0.239 sec)
# INFO:tensorflow:global_step/sec: 409.968
# INFO:tensorflow:loss = 6.706462e-06, step = 34701 (0.243 sec)
# INFO:tensorflow:global_step/sec: 437.059
# INFO:tensorflow:loss = 1.1443336e-05, step = 34801 (0.229 sec)
# INFO:tensorflow:global_step/sec: 441.777
# INFO:tensorflow:loss = 1.3722461e-05, step = 34901 (0.227 sec)
# INFO:tensorflow:global_step/sec: 416.14
# INFO:tensorflow:loss = 9.736398e-06, step = 35001 (0.240 sec)
# INFO:tensorflow:global_step/sec: 429.841
# INFO:tensorflow:loss = 1.2046513e-05, step = 35101 (0.232 sec)
# INFO:tensorflow:global_step/sec: 427.741
# INFO:tensorflow:loss = 6.2843565e-06, step = 35201 (0.234 sec)
# INFO:tensorflow:global_step/sec: 425.187
# INFO:tensorflow:loss = 6.992485e-06, step = 35301 (0.236 sec)
# INFO:tensorflow:global_step/sec: 425.763
# INFO:tensorflow:loss = 1.5698852e-05, step = 35401 (0.235 sec)
# INFO:tensorflow:global_step/sec: 411.323
# INFO:tensorflow:loss = 5.3449203e-06, step = 35501 (0.243 sec)
# INFO:tensorflow:global_step/sec: 451.003
# INFO:tensorflow:loss = 9.011605e-06, step = 35601 (0.222 sec)
# INFO:tensorflow:global_step/sec: 462.516
# INFO:tensorflow:loss = 9.834305e-06, step = 35701 (0.217 sec)
# INFO:tensorflow:global_step/sec: 451.6
# INFO:tensorflow:loss = 1.0658994e-05, step = 35801 (0.222 sec)
# INFO:tensorflow:global_step/sec: 450.405
# INFO:tensorflow:loss = 1.1095431e-05, step = 35901 (0.222 sec)
# INFO:tensorflow:global_step/sec: 451.726
# INFO:tensorflow:loss = 1.2511416e-05, step = 36001 (0.221 sec)
# INFO:tensorflow:global_step/sec: 426.773
# INFO:tensorflow:loss = 9.853176e-06, step = 36101 (0.234 sec)
# INFO:tensorflow:global_step/sec: 450.979
# INFO:tensorflow:loss = 9.200073e-06, step = 36201 (0.222 sec)
# INFO:tensorflow:global_step/sec: 451.461
# INFO:tensorflow:loss = 7.2022817e-06, step = 36301 (0.221 sec)
# INFO:tensorflow:global_step/sec: 461.507
# INFO:tensorflow:loss = 6.172245e-06, step = 36401 (0.217 sec)
# INFO:tensorflow:global_step/sec: 431.858
# INFO:tensorflow:loss = 1.15768935e-05, step = 36501 (0.232 sec)
# INFO:tensorflow:global_step/sec: 434.861
# INFO:tensorflow:loss = 7.1832446e-06, step = 36601 (0.230 sec)
# INFO:tensorflow:global_step/sec: 496.276
# INFO:tensorflow:loss = 7.981854e-06, step = 36701 (0.202 sec)
# INFO:tensorflow:global_step/sec: 536.313
# INFO:tensorflow:loss = 9.068894e-06, step = 36801 (0.186 sec)
# INFO:tensorflow:global_step/sec: 471.705
# INFO:tensorflow:loss = 1.2520992e-05, step = 36901 (0.215 sec)
# INFO:tensorflow:global_step/sec: 467.312
# INFO:tensorflow:loss = 1.0859282e-05, step = 37001 (0.210 sec)
# INFO:tensorflow:global_step/sec: 476.233
# INFO:tensorflow:loss = 4.6036807e-06, step = 37101 (0.210 sec)
# INFO:tensorflow:global_step/sec: 547.436
# INFO:tensorflow:loss = 4.846867e-06, step = 37201 (0.183 sec)
# INFO:tensorflow:global_step/sec: 439.322
# INFO:tensorflow:loss = 2.5796526e-06, step = 37301 (0.227 sec)
# INFO:tensorflow:global_step/sec: 414.959
# INFO:tensorflow:loss = 1.45402555e-05, step = 37401 (0.242 sec)
# INFO:tensorflow:global_step/sec: 451.693
# INFO:tensorflow:loss = 8.818576e-06, step = 37501 (0.221 sec)
# INFO:tensorflow:global_step/sec: 422.68
# INFO:tensorflow:loss = 1.4437746e-05, step = 37601 (0.236 sec)
# INFO:tensorflow:global_step/sec: 444.717
# INFO:tensorflow:loss = 7.199893e-06, step = 37701 (0.224 sec)
# INFO:tensorflow:global_step/sec: 429.012
# INFO:tensorflow:loss = 3.6833733e-06, step = 37801 (0.233 sec)
# INFO:tensorflow:global_step/sec: 438.4
# INFO:tensorflow:loss = 8.2774495e-06, step = 37901 (0.229 sec)
# INFO:tensorflow:global_step/sec: 456.859
# INFO:tensorflow:loss = 1.2704596e-05, step = 38001 (0.218 sec)
# INFO:tensorflow:global_step/sec: 470.371
# INFO:tensorflow:loss = 6.4011397e-06, step = 38101 (0.213 sec)
# INFO:tensorflow:global_step/sec: 470.314
# INFO:tensorflow:loss = 7.888914e-06, step = 38201 (0.213 sec)
# INFO:tensorflow:global_step/sec: 448.392
# INFO:tensorflow:loss = 9.993902e-06, step = 38301 (0.223 sec)
# INFO:tensorflow:global_step/sec: 442.624
# INFO:tensorflow:loss = 7.30942e-06, step = 38401 (0.226 sec)
# INFO:tensorflow:global_step/sec: 443.727
# INFO:tensorflow:loss = 1.4053937e-05, step = 38501 (0.226 sec)
# INFO:tensorflow:global_step/sec: 426.535
# INFO:tensorflow:loss = 4.889791e-06, step = 38601 (0.234 sec)
# INFO:tensorflow:global_step/sec: 435.889
# INFO:tensorflow:loss = 8.775602e-06, step = 38701 (0.229 sec)
# INFO:tensorflow:global_step/sec: 449.786
# INFO:tensorflow:loss = 4.3176246e-06, step = 38801 (0.223 sec)
# INFO:tensorflow:global_step/sec: 441.474
# INFO:tensorflow:loss = 1.1131127e-05, step = 38901 (0.226 sec)
# INFO:tensorflow:global_step/sec: 466.569
# INFO:tensorflow:loss = 6.0270518e-06, step = 39001 (0.215 sec)
# INFO:tensorflow:global_step/sec: 448.518
# INFO:tensorflow:loss = 4.7943886e-06, step = 39101 (0.223 sec)
# INFO:tensorflow:global_step/sec: 407.483
# INFO:tensorflow:loss = 6.9828384e-06, step = 39201 (0.245 sec)
# INFO:tensorflow:global_step/sec: 463.391
# INFO:tensorflow:loss = 5.7336583e-06, step = 39301 (0.216 sec)
# INFO:tensorflow:global_step/sec: 427.355
# INFO:tensorflow:loss = 1.1536408e-05, step = 39401 (0.234 sec)
# INFO:tensorflow:global_step/sec: 399.3
# INFO:tensorflow:loss = 8.692379e-06, step = 39501 (0.254 sec)
# INFO:tensorflow:global_step/sec: 403.291
# INFO:tensorflow:loss = 8.837614e-06, step = 39601 (0.244 sec)
# INFO:tensorflow:global_step/sec: 438.258
# INFO:tensorflow:loss = 5.738506e-06, step = 39701 (0.228 sec)
# INFO:tensorflow:global_step/sec: 425.976
# INFO:tensorflow:loss = 5.356911e-06, step = 39801 (0.235 sec)
# INFO:tensorflow:global_step/sec: 439.67
# INFO:tensorflow:loss = 8.97357e-06, step = 39901 (0.227 sec)
# INFO:tensorflow:Saving checkpoints for 40000 into /tmp/tmpm4ddjuee/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.9434224e-06.
# DNNClassifier(params={'head': <tensorflow.contrib.learn.python.learn.estimators.head._MultiClassHead object at 0x7fcdec24a7b8>, 'hidden_units': [300, 100], 'feature_columns': (_RealValuedColumn(column_name='', dimension=2, default_value=None, dtype=tf.float64, normalizer=None),), 'optimizer': None, 'activation_fn': <function relu at 0x7fce87ee69d8>, 'dropout': None, 'gradient_clip_norm': None, 'embedding_lr_multipliers': None, 'input_layer_min_slice_size': None})

# %% [markdown]
# Under the hood, DNNClassifier uses ReLU activation functions by default. This can be changed by setting the activation_fn hyperparameter.

# %%
from sklearn.metrics import accuracy_score

y_pred = list(dnn_clf.predict(X_test))
accuracy_score(y_test, y_pred)
# Out:
# WARNING:tensorflow:From /home/mwehr/.local/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:574: calling DNNClassifier.predict (from tensorflow.contrib.learn.python.learn.estimators.dnn) with outputs=None is deprecated and will be removed after 2017-03-01.
# Instructions for updating:
# Please switch to predict_classes, or set `outputs` argument.
# WARNING:tensorflow:From /home/mwehr/.local/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py:463: calling BaseEstimator.predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Graph was finalized.
# WARNING:tensorflow:From /home/mwehr/.local/lib/python3.6/site-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from /tmp/tmpm4ddjuee/model.ckpt-40000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 1.0

# %% [markdown]
# Tf.Learn also has its own function to evaluate models:

# %%
dnn_clf.evaluate(X_test, y_test)
# Out:
# WARNING:tensorflow:From <ipython-input-12-3d05cc408f91>:1: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-12-3d05cc408f91>:1: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Starting evaluation at 2020-05-13T20:51:40Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpm4ddjuee/model.ckpt-40000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-05-13-20:51:40
# INFO:tensorflow:Saving dict for global step 40000: accuracy = 1.0, global_step = 40000, loss = 1.8024381e-06
# {'accuracy': 1.0, 'global_step': 40000, 'loss': 1.8024381e-06}

# %% [markdown]
# ### X.2 Training a DNN Using Plain TensorFlow
#
# In this part, we will built the same model as before, and we will implement Minibatch Gradient Descent to train on the MNIST dataset. As always with tensorflow, we start with the construction phase, building the graph. In the second step, we run the graph to train the model.
#
# **Construction Phase**

# %%
import tensorflow as tf

n_inputs = 28*28 # the number of features --> each pixel = one feature
n_hidden1 = 300
n_hidden2 = 100
n_outputs = 10

# %% [markdown]
# I will create some placeholders for X and y. We do not know the batch size yet, which is why we insert 'None' for the first dimension. We do know the number of features though.

# %%
X = tf.placeholder(tf.float32, shape=(None, n_inputs), name='X')
y = tf.placeholder(tf.int64, shape=(None), name='y')

# %% [markdown]
# Next will be the actual structure of the neural network. Placeholder 'X' will be the input layer. During the execution phase, it will be replaced with one training batch at a time.

# %%
def neuron_layer(X, n_neurons, name, activation=None):
    with tf.name_scope(name):
        n_inputs = int(X.get_shape()[1])
        stddev = 2/np.sqrt(n_inputs)
        init = tf.truncated_normal((n_inputs, n_neurons), stddev=stddev)
        W = tf.Variable(init, name='weights')
        b = tf.Variable(tf.zeros([n_neurons]), name='bias')
        z = tf.matmul(X, W)+b
        if activation=='relu':
            return tf.nn.relu(z)
        else:
            return z

# %% [markdown]
# Let’s go through this code line by line:
# 1. First we create a name scope using the name of the layer: it will contain all the computation nodes for this neuron layer. This is optional, but the graph will look much nicer in TensorBoard if its nodes are well organized.
# 2. Next, we get the number of inputs by looking up the input matrix’s shape and getting the size of the second dimension (the first dimension is for instances).
# 3. The next three lines create a W variable that will hold the weights matrix. It will be a 2D tensor containing all the connection weights between each input and each neuron; hence, its shape will be (n_inputs, n_neurons). It will be initialized randomly, using a truncated10 normal (Gaussian) distribution with a standard deviation of 2/ ninputs. Using this specific standard deviation helps the algorithm converge much faster (we will discuss this further in Chapter 11; it is one of those small tweaks to neural networks that have had a tremendous impact on their efficiency). It is important to initialize connection weights randomly for all hidden layers to avoid any symmetries that the Gradient Descent algorithm would be unable to break.11
# 4. The next line creates a b variable for biases, initialized to 0 (no symmetry issue in this case), with one bias parameter per neuron.
# 5. Then we create a subgraph to compute z = X · W + b. This vectorized implementation will efficiently compute the weighted sums of the inputs plus the bias term for each and every neuron in the layer, for all the instances in the batch in just one shot.
# 6. Finally, if the activation parameter is set to "relu", the code returns relu(z) (i.e., max (0, z)), or else it just returns z.<br>
#
# Now we can create the actual DNN. The first hidden layer takes X as input, the second hidden layer takes the the output of the first hidden layer as input, and, finally, the output layer takes the output of the second hidden layer as input.

# %%
with tf.name_scope('dnn'):
    hidden1 = neuron_layer(X, n_hidden1, 'hidden1', activation='relu')
    hidden2 = neuron_layer(hidden1, n_hidden2, 'hidden2', activation='relu')
    logits = neuron_layer(hidden2, n_outputs, 'outputs')

# %% [markdown]
# Tensorflow actually provides a package, so that we do not need to write our own neuron layers. The fully_connected() function does exactly that. It also takes care of creating the weights and biases with the proper initialization strategy, and it uses ReLU by default.

# %%
from tensorflow.contrib.layers import fully_connected

with tf.name_scope('dnn'):
    hidden1 = fully_connected(X, n_hidden1, scope='hidden1')
    hidden2 = fully_connected(hidden1, n_hidden2, scope='hidden2')
    logits = fully_connected(hidden2, n_outputs, scope='outputs',
                             activation_fn=None)

# %% [markdown]
# Next, we need to choose a cost function to train our model on. For softmax, cross entropy is a good choice. Cross entropy penalizes models that estimate a low probability for the target class. Tensorflow's 'sparse_softmax_cross_entropy_with_logits()' function computes the entropy based on logits (output *before* going through the softmax activation function). This will result in a 1D tensor containing cross entropy for each instance. We can then use 'reduce_mean()' to compute the mean cross entropy over all instances.

# %%
with tf.name_scope('loss'):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y,
                                                             logits=logits)
    loss = tf.reduce_mean(xentropy, name='loss')

# %% [markdown]
# Next, we define the optimizer that will tweak the model parameters to minimize the cost function. Here we are using 'GradientDescentOptimizer'.

# %%
learning_rate = 0.01

with tf.name_scope('train'):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)

# %% [markdown]
# The last important step of the construction phase is to specify how to evaluate the model. For this we can simply use accuracy as our performance measure. We first determine if the neural network's prediction is correct by checking whether or not the highest logit corresponds to the target class (use 'in_top_k()' function). This returns a 1D tensor full of booleans, which we can then cast to floats and compute the average. This will return the networks overall accuracy.

# %%
with tf.name_scope('eval'):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# %% [markdown]
# We also need a node to initialize all variables, and we will need a Saver to save the trained model to disk:

# %%
init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %% [markdown]
# **Execution Phase**

# %%
from tensorflow.examples.tutorials.mnist import input_data

mnist = input_data.read_data_sets('/tmp/data/')
# Out:
# WARNING:tensorflow:From <ipython-input-23-cfd3bd6057da>:3: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /home/mwehr/.local/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /home/mwehr/.local/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# WARNING:tensorflow:From /home/mwehr/.local/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# WARNING:tensorflow:From /home/mwehr/.local/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/mwehr/.local/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %% [markdown]
# Next, we define the number of epochs and the size of the mini-batches and train the model:

# %%
n_epochs = 400
batch_size = 50

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for iteration in range(mnist.train.num_examples // batch_size):
            X_batch, y_batch = mnist.train.next_batch(batch_size)
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_train = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        acc_test = accuracy.eval(feed_dict={X: mnist.test.images,
                                           y: mnist.test.labels})
        print(epoch, 'Train accuracy:', acc_train, 'Test accuracy:', acc_test)
    save_path = saver.save(sess, './test_tensorflow_model.ckpt')
# Out:
# 0 Train accuracy: 0.84 Test accuracy: 0.905
# 1 Train accuracy: 0.88 Test accuracy: 0.9221
# 2 Train accuracy: 0.86 Test accuracy: 0.9305
# 3 Train accuracy: 0.96 Test accuracy: 0.9389
# 4 Train accuracy: 0.94 Test accuracy: 0.9418
# 5 Train accuracy: 0.98 Test accuracy: 0.9455
# 6 Train accuracy: 0.96 Test accuracy: 0.9506
# 7 Train accuracy: 0.96 Test accuracy: 0.9532
# 8 Train accuracy: 0.96 Test accuracy: 0.9558
# 9 Train accuracy: 0.94 Test accuracy: 0.9571
# 10 Train accuracy: 0.96 Test accuracy: 0.9588
# 11 Train accuracy: 0.94 Test accuracy: 0.9608
# 12 Train accuracy: 0.96 Test accuracy: 0.9624
# 13 Train accuracy: 1.0 Test accuracy: 0.964
# 14 Train accuracy: 1.0 Test accuracy: 0.964
# 15 Train accuracy: 1.0 Test accuracy: 0.9661
# 16 Train accuracy: 0.96 Test accuracy: 0.9666
# 17 Train accuracy: 0.96 Test accuracy: 0.9672
# 18 Train accuracy: 0.96 Test accuracy: 0.9684
# 19 Train accuracy: 0.96 Test accuracy: 0.9705
# 20 Train accuracy: 0.96 Test accuracy: 0.9716
# 21 Train accuracy: 1.0 Test accuracy: 0.9712
# 22 Train accuracy: 0.98 Test accuracy: 0.972
# 23 Train accuracy: 0.94 Test accuracy: 0.9731
# 24 Train accuracy: 0.96 Test accuracy: 0.9735
# 25 Train accuracy: 1.0 Test accuracy: 0.973
# 26 Train accuracy: 1.0 Test accuracy: 0.9733
# 27 Train accuracy: 0.96 Test accuracy: 0.9743
# 28 Train accuracy: 1.0 Test accuracy: 0.9738
# 29 Train accuracy: 1.0 Test accuracy: 0.9745
# 30 Train accuracy: 1.0 Test accuracy: 0.975
# 31 Train accuracy: 1.0 Test accuracy: 0.9759
# 32 Train accuracy: 0.98 Test accuracy: 0.9755
# 33 Train accuracy: 1.0 Test accuracy: 0.9759
# 34 Train accuracy: 0.98 Test accuracy: 0.9764
# 35 Train accuracy: 0.98 Test accuracy: 0.976
# 36 Train accuracy: 0.98 Test accuracy: 0.9764
# 37 Train accuracy: 0.98 Test accuracy: 0.9762
# 38 Train accuracy: 1.0 Test accuracy: 0.9771
# 39 Train accuracy: 1.0 Test accuracy: 0.9764
# 40 Train accuracy: 1.0 Test accuracy: 0.9777
# 41 Train accuracy: 1.0 Test accuracy: 0.9775
# 42 Train accuracy: 0.98 Test accuracy: 0.976
# 43 Train accuracy: 1.0 Test accuracy: 0.9772
# 44 Train accuracy: 1.0 Test accuracy: 0.9774
# 45 Train accuracy: 1.0 Test accuracy: 0.9782
# 46 Train accuracy: 1.0 Test accuracy: 0.9781
# 47 Train accuracy: 1.0 Test accuracy: 0.9787
# 48 Train accuracy: 1.0 Test accuracy: 0.9776
# 49 Train accuracy: 1.0 Test accuracy: 0.9771
# 50 Train accuracy: 1.0 Test accuracy: 0.9779
# 51 Train accuracy: 1.0 Test accuracy: 0.9773
# 52 Train accuracy: 1.0 Test accuracy: 0.9786
# 53 Train accuracy: 1.0 Test accuracy: 0.9776
# 54 Train accuracy: 1.0 Test accuracy: 0.978
# 55 Train accuracy: 1.0 Test accuracy: 0.9783
# 56 Train accuracy: 0.98 Test accuracy: 0.9784
# 57 Train accuracy: 1.0 Test accuracy: 0.978
# 58 Train accuracy: 1.0 Test accuracy: 0.9784
# 59 Train accuracy: 1.0 Test accuracy: 0.9783
# 60 Train accuracy: 1.0 Test accuracy: 0.9786
# 61 Train accuracy: 1.0 Test accuracy: 0.9788
# 62 Train accuracy: 1.0 Test accuracy: 0.9776
# 63 Train accuracy: 1.0 Test accuracy: 0.9784
# 64 Train accuracy: 1.0 Test accuracy: 0.9782
# 65 Train accuracy: 1.0 Test accuracy: 0.9782
# 66 Train accuracy: 1.0 Test accuracy: 0.9792
# 67 Train accuracy: 1.0 Test accuracy: 0.9782
# 68 Train accuracy: 1.0 Test accuracy: 0.978
# 69 Train accuracy: 1.0 Test accuracy: 0.9789
# 70 Train accuracy: 1.0 Test accuracy: 0.9782
# 71 Train accuracy: 1.0 Test accuracy: 0.9783
# 72 Train accuracy: 1.0 Test accuracy: 0.9781
# 73 Train accuracy: 1.0 Test accuracy: 0.9787
# 74 Train accuracy: 1.0 Test accuracy: 0.9786
# 75 Train accuracy: 1.0 Test accuracy: 0.9784
# 76 Train accuracy: 1.0 Test accuracy: 0.9786
# 77 Train accuracy: 1.0 Test accuracy: 0.9782
# 78 Train accuracy: 1.0 Test accuracy: 0.9779
# 79 Train accuracy: 1.0 Test accuracy: 0.9786
# 80 Train accuracy: 1.0 Test accuracy: 0.9782
# 81 Train accuracy: 1.0 Test accuracy: 0.9782
# 82 Train accuracy: 1.0 Test accuracy: 0.9785
# 83 Train accuracy: 1.0 Test accuracy: 0.9783
# 84 Train accuracy: 1.0 Test accuracy: 0.9781
# 85 Train accuracy: 1.0 Test accuracy: 0.9782
# 86 Train accuracy: 1.0 Test accuracy: 0.9783
# 87 Train accuracy: 0.98 Test accuracy: 0.9782
# 88 Train accuracy: 1.0 Test accuracy: 0.9784
# 89 Train accuracy: 1.0 Test accuracy: 0.9784
# 90 Train accuracy: 1.0 Test accuracy: 0.9784
# 91 Train accuracy: 1.0 Test accuracy: 0.9788
# 92 Train accuracy: 1.0 Test accuracy: 0.9779
# 93 Train accuracy: 1.0 Test accuracy: 0.9784
# 94 Train accuracy: 1.0 Test accuracy: 0.9784
# 95 Train accuracy: 1.0 Test accuracy: 0.979
# 96 Train accuracy: 1.0 Test accuracy: 0.9785
# 97 Train accuracy: 1.0 Test accuracy: 0.9784
# 98 Train accuracy: 1.0 Test accuracy: 0.9786
# 99 Train accuracy: 1.0 Test accuracy: 0.9786
# 100 Train accuracy: 1.0 Test accuracy: 0.9783
# 101 Train accuracy: 1.0 Test accuracy: 0.9786
# 102 Train accuracy: 1.0 Test accuracy: 0.9782
# 103 Train accuracy: 1.0 Test accuracy: 0.9789
# 104 Train accuracy: 1.0 Test accuracy: 0.9789
# 105 Train accuracy: 1.0 Test accuracy: 0.9786
# 106 Train accuracy: 1.0 Test accuracy: 0.9795
# 107 Train accuracy: 1.0 Test accuracy: 0.9787
# 108 Train accuracy: 1.0 Test accuracy: 0.9789
# 109 Train accuracy: 1.0 Test accuracy: 0.9786
# 110 Train accuracy: 1.0 Test accuracy: 0.9785
# 111 Train accuracy: 1.0 Test accuracy: 0.9786
# 112 Train accuracy: 1.0 Test accuracy: 0.9792
# 113 Train accuracy: 1.0 Test accuracy: 0.9788
# 114 Train accuracy: 1.0 Test accuracy: 0.9794
# 115 Train accuracy: 1.0 Test accuracy: 0.9788
# 116 Train accuracy: 1.0 Test accuracy: 0.9788
# 117 Train accuracy: 1.0 Test accuracy: 0.9784
# 118 Train accuracy: 1.0 Test accuracy: 0.9788
# 119 Train accuracy: 1.0 Test accuracy: 0.9792
# 120 Train accuracy: 1.0 Test accuracy: 0.9783
# 121 Train accuracy: 1.0 Test accuracy: 0.9786
# 122 Train accuracy: 1.0 Test accuracy: 0.9787
# 123 Train accuracy: 1.0 Test accuracy: 0.9792
# 124 Train accuracy: 1.0 Test accuracy: 0.9785
# 125 Train accuracy: 1.0 Test accuracy: 0.9786
# 126 Train accuracy: 1.0 Test accuracy: 0.9794
# 127 Train accuracy: 1.0 Test accuracy: 0.9786
# 128 Train accuracy: 1.0 Test accuracy: 0.9791
# 129 Train accuracy: 1.0 Test accuracy: 0.9793
# 130 Train accuracy: 1.0 Test accuracy: 0.979
# 131 Train accuracy: 1.0 Test accuracy: 0.9793
# 132 Train accuracy: 1.0 Test accuracy: 0.9794
# 133 Train accuracy: 1.0 Test accuracy: 0.9791
# 134 Train accuracy: 1.0 Test accuracy: 0.9789
# 135 Train accuracy: 1.0 Test accuracy: 0.9787
# 136 Train accuracy: 1.0 Test accuracy: 0.979
# 137 Train accuracy: 1.0 Test accuracy: 0.9785
# 138 Train accuracy: 1.0 Test accuracy: 0.9793
# 139 Train accuracy: 1.0 Test accuracy: 0.9793
# 140 Train accuracy: 1.0 Test accuracy: 0.9793
# 141 Train accuracy: 1.0 Test accuracy: 0.9785
# 142 Train accuracy: 1.0 Test accuracy: 0.9783
# 143 Train accuracy: 1.0 Test accuracy: 0.979
# 144 Train accuracy: 1.0 Test accuracy: 0.9788
# 145 Train accuracy: 1.0 Test accuracy: 0.9791
# 146 Train accuracy: 1.0 Test accuracy: 0.9796
# 147 Train accuracy: 1.0 Test accuracy: 0.9793
# 148 Train accuracy: 1.0 Test accuracy: 0.9788
# 149 Train accuracy: 1.0 Test accuracy: 0.9794
# 150 Train accuracy: 1.0 Test accuracy: 0.9792
# 151 Train accuracy: 1.0 Test accuracy: 0.9793
# 152 Train accuracy: 1.0 Test accuracy: 0.9792
# 153 Train accuracy: 1.0 Test accuracy: 0.9789
# 154 Train accuracy: 1.0 Test accuracy: 0.9792
# 155 Train accuracy: 1.0 Test accuracy: 0.9796
# 156 Train accuracy: 1.0 Test accuracy: 0.9793
# 157 Train accuracy: 1.0 Test accuracy: 0.9789
# 158 Train accuracy: 1.0 Test accuracy: 0.9792
# 159 Train accuracy: 1.0 Test accuracy: 0.9794
# 160 Train accuracy: 1.0 Test accuracy: 0.9791
# 161 Train accuracy: 1.0 Test accuracy: 0.9794
# 162 Train accuracy: 1.0 Test accuracy: 0.9793
# 163 Train accuracy: 1.0 Test accuracy: 0.9796
# 164 Train accuracy: 1.0 Test accuracy: 0.9793
# 165 Train accuracy: 1.0 Test accuracy: 0.9789
# 166 Train accuracy: 1.0 Test accuracy: 0.9797
# 167 Train accuracy: 1.0 Test accuracy: 0.9794
# 168 Train accuracy: 1.0 Test accuracy: 0.9788
# 169 Train accuracy: 1.0 Test accuracy: 0.9796
# 170 Train accuracy: 1.0 Test accuracy: 0.9795
# 171 Train accuracy: 1.0 Test accuracy: 0.9794
# 172 Train accuracy: 1.0 Test accuracy: 0.9794
# 173 Train accuracy: 1.0 Test accuracy: 0.9795
# 174 Train accuracy: 1.0 Test accuracy: 0.9791
# 175 Train accuracy: 1.0 Test accuracy: 0.9791
# 176 Train accuracy: 1.0 Test accuracy: 0.9791
# 177 Train accuracy: 1.0 Test accuracy: 0.9795
# 178 Train accuracy: 1.0 Test accuracy: 0.9791
# 179 Train accuracy: 1.0 Test accuracy: 0.9794
# 180 Train accuracy: 1.0 Test accuracy: 0.9792
# 181 Train accuracy: 1.0 Test accuracy: 0.9794
# 182 Train accuracy: 1.0 Test accuracy: 0.9794
# 183 Train accuracy: 1.0 Test accuracy: 0.9794
# 184 Train accuracy: 1.0 Test accuracy: 0.9793
# 185 Train accuracy: 1.0 Test accuracy: 0.9795
# 186 Train accuracy: 1.0 Test accuracy: 0.9793
# 187 Train accuracy: 1.0 Test accuracy: 0.9792
# 188 Train accuracy: 1.0 Test accuracy: 0.9793
# 189 Train accuracy: 1.0 Test accuracy: 0.9791
# 190 Train accuracy: 1.0 Test accuracy: 0.9792
# 191 Train accuracy: 1.0 Test accuracy: 0.9792
# 192 Train accuracy: 1.0 Test accuracy: 0.9796
# 193 Train accuracy: 1.0 Test accuracy: 0.9791
# 194 Train accuracy: 1.0 Test accuracy: 0.9796
# 195 Train accuracy: 1.0 Test accuracy: 0.9794
# 196 Train accuracy: 1.0 Test accuracy: 0.9788
# 197 Train accuracy: 1.0 Test accuracy: 0.9793
# 198 Train accuracy: 1.0 Test accuracy: 0.9793
# 199 Train accuracy: 1.0 Test accuracy: 0.9791
# 200 Train accuracy: 1.0 Test accuracy: 0.9793
# 201 Train accuracy: 1.0 Test accuracy: 0.9794
# 202 Train accuracy: 1.0 Test accuracy: 0.9795
# 203 Train accuracy: 1.0 Test accuracy: 0.9795
# 204 Train accuracy: 1.0 Test accuracy: 0.9793
# 205 Train accuracy: 1.0 Test accuracy: 0.9791
# 206 Train accuracy: 1.0 Test accuracy: 0.9794
# 207 Train accuracy: 1.0 Test accuracy: 0.9795
# 208 Train accuracy: 1.0 Test accuracy: 0.9793
# 209 Train accuracy: 1.0 Test accuracy: 0.9793
# 210 Train accuracy: 1.0 Test accuracy: 0.9793
# 211 Train accuracy: 1.0 Test accuracy: 0.9793
# 212 Train accuracy: 1.0 Test accuracy: 0.9793
# 213 Train accuracy: 1.0 Test accuracy: 0.9794
# 214 Train accuracy: 1.0 Test accuracy: 0.979
# 215 Train accuracy: 1.0 Test accuracy: 0.9789
# 216 Train accuracy: 1.0 Test accuracy: 0.9793
# 217 Train accuracy: 1.0 Test accuracy: 0.9791
# 218 Train accuracy: 1.0 Test accuracy: 0.979
# 219 Train accuracy: 1.0 Test accuracy: 0.9792
# 220 Train accuracy: 1.0 Test accuracy: 0.9794
# 221 Train accuracy: 1.0 Test accuracy: 0.9793
# 222 Train accuracy: 1.0 Test accuracy: 0.9796
# 223 Train accuracy: 1.0 Test accuracy: 0.9794
# 224 Train accuracy: 1.0 Test accuracy: 0.9793
# 225 Train accuracy: 1.0 Test accuracy: 0.979
# 226 Train accuracy: 1.0 Test accuracy: 0.9794
# 227 Train accuracy: 1.0 Test accuracy: 0.9792
# 228 Train accuracy: 1.0 Test accuracy: 0.9791
# 229 Train accuracy: 1.0 Test accuracy: 0.9793
# 230 Train accuracy: 1.0 Test accuracy: 0.9793
# 231 Train accuracy: 1.0 Test accuracy: 0.9793
# 232 Train accuracy: 1.0 Test accuracy: 0.9787
# 233 Train accuracy: 1.0 Test accuracy: 0.9792
# 234 Train accuracy: 1.0 Test accuracy: 0.9791
# 235 Train accuracy: 1.0 Test accuracy: 0.9792
# 236 Train accuracy: 1.0 Test accuracy: 0.9793
# 237 Train accuracy: 1.0 Test accuracy: 0.9793
# 238 Train accuracy: 1.0 Test accuracy: 0.979
# 239 Train accuracy: 1.0 Test accuracy: 0.9793
# 240 Train accuracy: 1.0 Test accuracy: 0.9793
# 241 Train accuracy: 1.0 Test accuracy: 0.9792
# 242 Train accuracy: 1.0 Test accuracy: 0.9792
# 243 Train accuracy: 1.0 Test accuracy: 0.979
# 244 Train accuracy: 1.0 Test accuracy: 0.9791
# 245 Train accuracy: 1.0 Test accuracy: 0.9791
# 246 Train accuracy: 1.0 Test accuracy: 0.9793
# 247 Train accuracy: 1.0 Test accuracy: 0.9793
# 248 Train accuracy: 1.0 Test accuracy: 0.9793
# 249 Train accuracy: 1.0 Test accuracy: 0.9793
# 250 Train accuracy: 1.0 Test accuracy: 0.9792
# 251 Train accuracy: 1.0 Test accuracy: 0.9794
# 252 Train accuracy: 1.0 Test accuracy: 0.9792
# 253 Train accuracy: 1.0 Test accuracy: 0.979
# 254 Train accuracy: 1.0 Test accuracy: 0.9789
# 255 Train accuracy: 1.0 Test accuracy: 0.9793
# 256 Train accuracy: 1.0 Test accuracy: 0.979
# 257 Train accuracy: 1.0 Test accuracy: 0.9791
# 258 Train accuracy: 1.0 Test accuracy: 0.9792
# 259 Train accuracy: 1.0 Test accuracy: 0.9791
# 260 Train accuracy: 1.0 Test accuracy: 0.9791
# 261 Train accuracy: 1.0 Test accuracy: 0.979
# 262 Train accuracy: 1.0 Test accuracy: 0.9791
# 263 Train accuracy: 1.0 Test accuracy: 0.9793
# 264 Train accuracy: 1.0 Test accuracy: 0.9791
# 265 Train accuracy: 1.0 Test accuracy: 0.979
# 266 Train accuracy: 1.0 Test accuracy: 0.9791
# 267 Train accuracy: 1.0 Test accuracy: 0.9792
# 268 Train accuracy: 1.0 Test accuracy: 0.979
# 269 Train accuracy: 1.0 Test accuracy: 0.9792
# 270 Train accuracy: 1.0 Test accuracy: 0.9793
# 271 Train accuracy: 1.0 Test accuracy: 0.9791
# 272 Train accuracy: 1.0 Test accuracy: 0.9793
# 273 Train accuracy: 1.0 Test accuracy: 0.979
# 274 Train accuracy: 1.0 Test accuracy: 0.9791
# 275 Train accuracy: 1.0 Test accuracy: 0.9789
# 276 Train accuracy: 1.0 Test accuracy: 0.9791
# 277 Train accuracy: 1.0 Test accuracy: 0.9793
# 278 Train accuracy: 1.0 Test accuracy: 0.9791
# 279 Train accuracy: 1.0 Test accuracy: 0.9789
# 280 Train accuracy: 1.0 Test accuracy: 0.979
# 281 Train accuracy: 1.0 Test accuracy: 0.9791
# 282 Train accuracy: 1.0 Test accuracy: 0.9791
# 283 Train accuracy: 1.0 Test accuracy: 0.9791
# 284 Train accuracy: 1.0 Test accuracy: 0.9792
# 285 Train accuracy: 1.0 Test accuracy: 0.9793
# 286 Train accuracy: 1.0 Test accuracy: 0.9793
# 287 Train accuracy: 1.0 Test accuracy: 0.9795
# 288 Train accuracy: 1.0 Test accuracy: 0.9792
# 289 Train accuracy: 1.0 Test accuracy: 0.9792
# 290 Train accuracy: 1.0 Test accuracy: 0.9792
# 291 Train accuracy: 1.0 Test accuracy: 0.9789
# 292 Train accuracy: 1.0 Test accuracy: 0.9793
# 293 Train accuracy: 1.0 Test accuracy: 0.9791
# 294 Train accuracy: 1.0 Test accuracy: 0.979
# 295 Train accuracy: 1.0 Test accuracy: 0.9791
# 296 Train accuracy: 1.0 Test accuracy: 0.9791
# 297 Train accuracy: 1.0 Test accuracy: 0.9791
# 298 Train accuracy: 1.0 Test accuracy: 0.9789
# 299 Train accuracy: 1.0 Test accuracy: 0.9789
# 300 Train accuracy: 1.0 Test accuracy: 0.9791
# 301 Train accuracy: 1.0 Test accuracy: 0.9791
# 302 Train accuracy: 1.0 Test accuracy: 0.9792
# 303 Train accuracy: 1.0 Test accuracy: 0.9793
# 304 Train accuracy: 1.0 Test accuracy: 0.9792
# 305 Train accuracy: 1.0 Test accuracy: 0.9791
# 306 Train accuracy: 1.0 Test accuracy: 0.979
# 307 Train accuracy: 1.0 Test accuracy: 0.9789
# 308 Train accuracy: 1.0 Test accuracy: 0.9792
# 309 Train accuracy: 1.0 Test accuracy: 0.979
# 310 Train accuracy: 1.0 Test accuracy: 0.9789
# 311 Train accuracy: 1.0 Test accuracy: 0.9792
# 312 Train accuracy: 1.0 Test accuracy: 0.9791
# 313 Train accuracy: 1.0 Test accuracy: 0.9793
# 314 Train accuracy: 1.0 Test accuracy: 0.9791
# 315 Train accuracy: 1.0 Test accuracy: 0.979
# 316 Train accuracy: 1.0 Test accuracy: 0.9793
# 317 Train accuracy: 1.0 Test accuracy: 0.9792
# 318 Train accuracy: 1.0 Test accuracy: 0.9791
# 319 Train accuracy: 1.0 Test accuracy: 0.9791
# 320 Train accuracy: 1.0 Test accuracy: 0.9789
# 321 Train accuracy: 1.0 Test accuracy: 0.9791
# 322 Train accuracy: 1.0 Test accuracy: 0.9791
# 323 Train accuracy: 1.0 Test accuracy: 0.9792
# 324 Train accuracy: 1.0 Test accuracy: 0.979
# 325 Train accuracy: 1.0 Test accuracy: 0.9791
# 326 Train accuracy: 1.0 Test accuracy: 0.9795
# 327 Train accuracy: 1.0 Test accuracy: 0.979
# 328 Train accuracy: 1.0 Test accuracy: 0.9792
# 329 Train accuracy: 1.0 Test accuracy: 0.9792
# 330 Train accuracy: 1.0 Test accuracy: 0.979
# 331 Train accuracy: 1.0 Test accuracy: 0.979
# 332 Train accuracy: 1.0 Test accuracy: 0.9792
# 333 Train accuracy: 1.0 Test accuracy: 0.9792
# 334 Train accuracy: 1.0 Test accuracy: 0.9791
# 335 Train accuracy: 1.0 Test accuracy: 0.9791
# 336 Train accuracy: 1.0 Test accuracy: 0.9788
# 337 Train accuracy: 1.0 Test accuracy: 0.9791
# 338 Train accuracy: 1.0 Test accuracy: 0.9791
# 339 Train accuracy: 1.0 Test accuracy: 0.9791
# 340 Train accuracy: 1.0 Test accuracy: 0.9791
# 341 Train accuracy: 1.0 Test accuracy: 0.9792
# 342 Train accuracy: 1.0 Test accuracy: 0.9792
# 343 Train accuracy: 1.0 Test accuracy: 0.9791
# 344 Train accuracy: 1.0 Test accuracy: 0.9791
# 345 Train accuracy: 1.0 Test accuracy: 0.9792
# 346 Train accuracy: 1.0 Test accuracy: 0.9792
# 347 Train accuracy: 1.0 Test accuracy: 0.9791
# 348 Train accuracy: 1.0 Test accuracy: 0.9792
# 349 Train accuracy: 1.0 Test accuracy: 0.9791
# 350 Train accuracy: 1.0 Test accuracy: 0.9791
# 351 Train accuracy: 1.0 Test accuracy: 0.9793
# 352 Train accuracy: 1.0 Test accuracy: 0.9792
# 353 Train accuracy: 1.0 Test accuracy: 0.9793
# 354 Train accuracy: 1.0 Test accuracy: 0.979
# 355 Train accuracy: 1.0 Test accuracy: 0.9791
# 356 Train accuracy: 1.0 Test accuracy: 0.9795
# 357 Train accuracy: 1.0 Test accuracy: 0.9794
# 358 Train accuracy: 1.0 Test accuracy: 0.9794
# 359 Train accuracy: 1.0 Test accuracy: 0.9791
# 360 Train accuracy: 1.0 Test accuracy: 0.9791
# 361 Train accuracy: 1.0 Test accuracy: 0.9792
# 362 Train accuracy: 1.0 Test accuracy: 0.9793
# 363 Train accuracy: 1.0 Test accuracy: 0.9792
# 364 Train accuracy: 1.0 Test accuracy: 0.9791
# 365 Train accuracy: 1.0 Test accuracy: 0.9792
# 366 Train accuracy: 1.0 Test accuracy: 0.979
# 367 Train accuracy: 1.0 Test accuracy: 0.9794
# 368 Train accuracy: 1.0 Test accuracy: 0.9792
# 369 Train accuracy: 1.0 Test accuracy: 0.9793
# 370 Train accuracy: 1.0 Test accuracy: 0.9791
# 371 Train accuracy: 1.0 Test accuracy: 0.9793
# 372 Train accuracy: 1.0 Test accuracy: 0.9794
# 373 Train accuracy: 1.0 Test accuracy: 0.9791
# 374 Train accuracy: 1.0 Test accuracy: 0.9793
# 375 Train accuracy: 1.0 Test accuracy: 0.979
# 376 Train accuracy: 1.0 Test accuracy: 0.9792
# 377 Train accuracy: 1.0 Test accuracy: 0.9794
# 378 Train accuracy: 1.0 Test accuracy: 0.9792
# 379 Train accuracy: 1.0 Test accuracy: 0.9793
# 380 Train accuracy: 1.0 Test accuracy: 0.9792
# 381 Train accuracy: 1.0 Test accuracy: 0.9792
# 382 Train accuracy: 1.0 Test accuracy: 0.9793
# 383 Train accuracy: 1.0 Test accuracy: 0.979
# 384 Train accuracy: 1.0 Test accuracy: 0.9792
# 385 Train accuracy: 1.0 Test accuracy: 0.9792
# 386 Train accuracy: 1.0 Test accuracy: 0.979
# 387 Train accuracy: 1.0 Test accuracy: 0.9793
# 388 Train accuracy: 1.0 Test accuracy: 0.9794
# 389 Train accuracy: 1.0 Test accuracy: 0.9792
# 390 Train accuracy: 1.0 Test accuracy: 0.9791
# 391 Train accuracy: 1.0 Test accuracy: 0.9792
# 392 Train accuracy: 1.0 Test accuracy: 0.9792
# 393 Train accuracy: 1.0 Test accuracy: 0.9792
# 394 Train accuracy: 1.0 Test accuracy: 0.9794
# 395 Train accuracy: 1.0 Test accuracy: 0.9793
# 396 Train accuracy: 1.0 Test accuracy: 0.9793
# 397 Train accuracy: 1.0 Test accuracy: 0.9793
# 398 Train accuracy: 1.0 Test accuracy: 0.9794
# 399 Train accuracy: 1.0 Test accuracy: 0.9792

# %% [markdown]
# To use the saved neural network for new data, change the execution phase as follows:

# %%
with tf.Session() as sess:
    saver.restore(sess, './test_tensorflow_model.ckpt')
    X_new_scaled = [...] # Some new images (scaled from 0 to 1)
    Z = logits.eval(feed_dicts={X: X_new_scaled})
    y_pred = np.argmax(Z, axis=1)

# %% [markdown]
# ### X.3 Fine-Tuning Neural Network Hyperparameters
#
# A neural network has a lot of different hyperparameters to tune. To name just a few, obvious ones: number of layers, number of neurons per layer, type of activation function to use in each layer, weight initialization logic etc. Using grid-search to find all the right parameters would be too costly. Using a **randomized search** or a tool such as [Oscar](http://oscar.calldesk.ai/) would be much better.
#
# #### X.3.1 Number of Hidden Layers
#
# Start with one or two layers and work your way up, if needed. Remember, nets with more layers need less neurons per layer to model the same complexity, and are, therefore, more efficient to train. Also, more layers usually make neural nets more generalizable. Add layers until you overfit the data. When that point is reached stop.
#
# #### X.3.2 Number of Neurons per Hidden Layer
#
# Obviously, the number of neurons for the input and output layers is determined by the number of features (input) and classes/categories (output). As for the hidden layers, it makes sense, from a logical perspective, to use fewer and fewer neurons per layer, since the first layers evaluate low-level structures (like lines for images), the intermediate layers combine these levels to evaluate intermediate-level-structures (like squares etc.), and the highest hidden layers combine the intermediate levels to model high-level structures (like faces etc). However, you could also use the same number of neurons for all layers. It would just take a bit longer to train.<br>
#
# One way to start is to gradually increase the number of neurons until it starts overfitting. Alternativly, you could use a very large number of neurons, more than you need, and implement an early-stopping policy to prevent it from overfitting (*streth pants approach*).
#
# #### X.3.3 Activation Functions
#
# For hidden layers, ReLU will mostly be a good choice, as it is fast to compute and does not saturate for large input values, because of which it will not get stuck on plateaus as easily (as opposed to the logistic function or the hyperbolic tangent function).<br>
#
# For classification tasks, use a softmax function in the end. For regression tasks, use no funtion at all.<br>
